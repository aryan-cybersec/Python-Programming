# %% [markdown]
# Question1: Create numpy array to find sum of all elements in an array.

# %%
# Import numpy library
import numpy as np

# Create a numpy array
arr = np.array([10, 20, 30, 40, 50])

# Find sum of all elements
total_sum = np.sum(arr)

# Display array and sum
print("Array:", arr)
print("Sum of all elements:", total_sum)
# Out:
# Array: [10 20 30 40 50]
# Sum of all elements: 150

# %% [markdown]
# Question2. Create numpy array of (3,3) dimension. Now find sum of all rows & columns
# individually. Also find 2nd maximum element in the array.

# %%
import numpy as np

# Create 3x3 numpy array
arr = np.array([[10, 20, 30],
                [40, 50, 60],
                [70, 80, 90]])

print("Array:\n", arr)

# Sum of rows (axis = 1)
row_sum = np.sum(arr, axis=1)
print("\nSum of each row:", row_sum)

# Sum of columns (axis = 0)
col_sum = np.sum(arr, axis=0)
print("Sum of each column:", col_sum)

# Find 2nd maximum element
flat = arr.flatten()     # convert to 1D array
second_max = np.sort(flat)[-2]

print("Second maximum element:", second_max)
# Out:
# Array:
#  [[10 20 30]
#  [40 50 60]
#  [70 80 90]]
#
# Sum of each row: [ 60 150 240]
# Sum of each column: [120 150 180]
# Second maximum element: 80

# %% [markdown]
# Question3. Perform Matrix multiplication of any 2 n*n matrices.

# %%
import numpy as np

# Function to safely take matrix input
def get_matrix(n, name):
    matrix = []
    print(f"\nEnter elements of {name} Matrix (each row must have {n} values):")
    
    for i in range(n):
        while True:
            try:
                row = list(map(int, input().split()))
                
                # Check row length
                if len(row) != n:
                    print(f"Please enter exactly {n} values!")
                    continue
                
                matrix.append(row)
                break
            except ValueError:
                print("Enter valid numbers only!")
    
    return np.array(matrix)

# Take size
n = int(input("Enter size of matrix (n x n): "))

# Take matrices safely
A = get_matrix(n, "First")
B = get_matrix(n, "Second")

# Matrix multiplication
result = A @ B

print("\nFirst Matrix:\n", A)
print("\nSecond Matrix:\n", B)
print("\nResult of Multiplication:\n", result)
# Out:
# Enter elements of First Matrix (each row must have 3 values):
# Please enter exactly 3 values!
# Please enter exactly 3 values!
# Please enter exactly 3 values!
# Please enter exactly 3 values!
# Please enter exactly 3 values!
# Please enter exactly 3 values!
# Please enter exactly 3 values!
# Please enter exactly 3 values!
#
# Enter elements of Second Matrix (each row must have 3 values):
#
# First Matrix:
#  [[ 1  3  4]
#  [ 5 45  3]
#  [ 3  5  3]]
#
# Second Matrix:
#  [[2 3 5]
#  [4 5 6]
#  [6 7 8]]
#
# Result of Multiplication:
#  [[ 38  46  55]
#  [208 261 319]
#  [ 44  55  69]]

# %% [markdown]
# Question4. Write a Pandas program to get the powers of an array values element-wise.
# Note: First array elements raised to powers from second array
# Sample data: {'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]}
# Expected Output:
# X Y Z
# 0 78 84 86
# 1 85 94 97
# 2 96 89 96
# 3 80 83 72
# 4 86 86 83

# %%
#Solution:
import pandas as pd

# Create the dataframe using given data
data = {'X':[78,85,96,80,86],
        'Y':[84,94,89,83,86],
        'Z':[86,97,96,72,83]}

df = pd.DataFrame(data)

print("Original DataFrame:\n")
print(df)

# Get first row values
first_row = df.iloc[0]

# Raise all rows to power of first row values (element-wise)
result = df.pow(first_row)

print("\nResult after applying power:\n")
print(result)
# Out:
# Original DataFrame:
#
#     X   Y   Z
# 0  78  84  86
# 1  85  94  97
# 2  96  89  96
# 3  80  83  72
# 4  86  86  83
#
# Result after applying power:
#
#                      X                    Y                    Z
# 0                    0                    0                    0
# 1 -8958867019779417143                    0  3447931455987522625
# 2                    0  6879641450804514913                    0
# 3                    0  7612148598749674321                    0
# 4                    0                    0 -4001704769748846919

# %% [markdown]
# Question5. Write a Pandas program to get the first 3 rows of a given DataFrame.
# Sample Python dictionary data and list labels:
# exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily',
# 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
# 'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
# 'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
# 'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# Expected Output:
# First three rows of the data frame:
# attempts name qualify score
# a 1 Anastasia yes 12.5
# b 3 Dima no 9.0
# c 2 Katherine yes 16.5

# %%
import pandas as pd
import numpy as np

# Given dictionary data
exam_data = {
    'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily',
             'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
    'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
    'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
    'qualify': ['yes', 'no', 'yes', 'no', 'no',
                'yes', 'yes', 'no', 'no', 'yes']
}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# Create DataFrame
df = pd.DataFrame(exam_data, index=labels)

# Get first 3 rows
first_three = df.head(3)

print("First three rows of the data frame:\n")
print(first_three)
# Out:
# First three rows of the data frame:
#
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes

# %% [markdown]
# Question6. Write a Pandas program to find and replace the missing values in a given
# DataFrame which do not have any valuable information.

# %%
import pandas as pd
import numpy as np

# Sample DataFrame with missing values
data = {
    'Name': ['Aman', 'Riya', 'Rahul', 'Sneha', 'Karan'],
    'Marks': [85, np.nan, 78, np.nan, 90],
    'City': ['Delhi', 'Mumbai', None, 'Pune', None]
}

df = pd.DataFrame(data)

print("Original DataFrame:\n")
print(df)

# Find missing values
print("\nMissing values in DataFrame:\n")
print(df.isnull())

# Replace missing numeric values with mean
df['Marks'].fillna(df['Marks'].mean(), inplace=True)

# Replace missing text values with 'Unknown'
df['City'].fillna("Unknown", inplace=True)

print("\nDataFrame after replacing missing values:\n")
print(df)
# Out:
# Original DataFrame:
#
#     Name  Marks    City
# 0   Aman   85.0   Delhi
# 1   Riya    NaN  Mumbai
# 2  Rahul   78.0     NaN
# 3  Sneha    NaN    Pune
# 4  Karan   90.0     NaN
#
# Missing values in DataFrame:
#
#     Name  Marks   City
# 0  False  False  False
# 1  False   True  False
# 2  False  False   True
# 3  False   True  False
# 4  False  False   True
#
# DataFrame after replacing missing values:
#
#     Name  Marks    City
# 0   Aman   85.0   Delhi
# 1   Riya    NaN  Mumbai
# 2  Rahul   78.0     NaN
# 3  Sneha    NaN    Pune
# 4  Karan   90.0     NaN
# C:\Users\bhavy\AppData\Local\Temp\ipykernel_13668\3820384058.py:21: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# ...

# %% [markdown]
# Question7. Create a program to demonstrate different visual forms using Matplotlib

# %%
import matplotlib.pyplot as plt

# Sample data
subjects = ['Physics', 'Chemistry', 'Maths', 'English']
marks = [85, 78, 92, 74]

# 1️⃣ Line Graph
plt.figure()
plt.plot(subjects, marks, marker='o')
plt.title("Line Graph - Marks")
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# 2️⃣ Bar Graph
plt.figure()
plt.bar(subjects, marks)
plt.title("Bar Graph - Marks")
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# 3️⃣ Scatter Plot
plt.figure()
plt.scatter(subjects, marks)
plt.title("Scatter Plot - Marks")
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# 4️⃣ Pie Chart
plt.figure()
plt.pie(marks, labels=subjects, autopct='%1.1f%%')
plt.title("Pie Chart - Marks Distribution")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
